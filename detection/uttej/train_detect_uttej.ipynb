# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 17516 (delta 8), reused 0 (delta 0), pack-reused 17494 (from 3)
# Receiving objects: 100% (17516/17516), 16.62 MiB | 31.40 MiB/s, done.
# Resolving deltas: 100% (12004/12004), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 37.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2212e96e-2227-4ff0-9895-c066e826a235" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2212e96e-2227-4ff0-9895-c066e826a235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d uttejkumarkandagatla/fall-detection-dataset
# !unzip -q fall-detection-dataset.zip -d fall_raw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uttejkumarkandagatla/fall-detection-dataset
# License(s): ODbL-1.0
# ...
#   0% 0.00/49.7M [00:00<?, ?B/s]
# 100% 49.7M/49.7M [00:00<00:00, 1.27GB/s]

# %%
# !ls fall_raw/
# Out:
# fall_dataset

# %%
with open("fall_data.yaml", "w") as f:
    f.write("""
train: /content/yolov5/fall_raw/fall_dataset/images
val: /content/yolov5/fall_raw/fall_dataset/val

nc: 3
names: ['Fall Detected', 'Walking', 'Sitting']
""")

# %%
# %cd /content/yolov5

# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data /content/yolov5/fall_data.yaml \
  --weights yolov5s.pt \
  --project runs/train \
  --name kaggle_uttej_run \
  --exist-ok
# Out:
# /content/yolov5
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-31 08:14:58.111973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753949698.133745    2211 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !ls /content/yolov5/fall_raw/fall_dataset/images/val | head
# Out:
# fall001.jpg
# fall002.jpg
# fall003.jpg
# fall004.jpg
# fall005.jpg
# fall006.jpg
# fall007.jpg
# fall008.jpg
# fall009.jpg
# fall010.jpg

# %%
# !python detect.py \
  --weights /content/yolov5/runs/train/kaggle_uttej_run/weights/best.pt \
  --source /content/test_images \
  --data /content/yolov5/fall_data.yaml \
  --img 640 \
  --conf 0.3 \
  --name uttej_detect_test \
  --save-txt \
  --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/kaggle_uttej_run/weights/best.pt'], source=/content/test_images, data=/content/yolov5/fall_data.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=uttej_detect_test, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3 /content/test_images/0qlfpu9w.jpg: 640x640 1 Walking, 7.2ms
# image 2/3 /content/test_images/170020221-slip-and-fall-accident-on-stairs-worker-woman-fallen-down.jpg: 448x640 1 Fall Detected, 38.9ms
# ...
