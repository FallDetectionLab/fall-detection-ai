# %% [markdown]
# <a href="https://colab.research.google.com/github/jinjinjaraxoxo/fall-detection-ai/blob/main/train_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jinjinjaraxoxo/fall-detection-ai.git
# Out:
# Cloning into 'fall-detection-ai'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 7.22 KiB | 7.22 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd fall-detection-ai/
# Out:
# /content/fall-detection-ai

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17496, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 17496 (delta 2), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17496/17496), 16.59 MiB | 29.04 MiB/s, done.
# Resolving deltas: 100% (11993/11993), done.
# /content/fall-detection-ai/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-88f4d25c-86ae-45bb-a831-e9d1a97bee2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88f4d25c-86ae-45bb-a831-e9d1a97bee2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d uttejkumarkandagatla/fall-detection-dataset
# !unzip fall-detection-dataset.zip -d /content/fall_raw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uttejkumarkandagatla/fall-detection-dataset
# License(s): ODbL-1.0
# ...
#   0% 0.00/49.7M [00:00<?, ?B/s]
# 100% 49.7M/49.7M [00:00<00:00, 1.39GB/s]
# Archive:  fall-detection-dataset.zip
#   inflating: /content/fall_raw/fall_dataset/images/train/fall001.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall002.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall003.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall004.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall005.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall006.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall007.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall008.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall009.jpg
#   inflating: /content/fall_raw/fall_dataset/images/train/fall010.jpg
# ...

# %%
yaml = """
train: /content/fall_dataset/images/train
val: /content/fall_dataset/images/val

nc: 2
names: ['normal', 'fall']
"""

with open('/content/fall_data.yaml', 'w') as f:
    f.write(yaml)

# %%
# !rm /content/fall_dataset/labels/train.cache
# !rm /content/fall_dataset/labels/val.cache
# Out:
# rm: cannot remove '/content/fall_dataset/labels/val.cache': No such file or directory

# %%
# 클래스 번호가 2 또는 2.0으로 시작하는 라인 전부 → 1로 변경
# !find /content/fall_dataset/labels/train -name "*.txt" -exec sed -i 's/^2[.0]* /1 /' {} \;
# !find /content/fall_dataset/labels/val -name "*.txt" -exec sed -i 's/^2[.0]* /1 /' {} \;

# %%
# %cd /content/fall-detection-ai/yolov5

# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data /content/fall_data.yaml \
  --weights yolov5s.pt
# Out:
# /content/fall-detection-ai/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-02 00:02:53.998556: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751414574.018717   11546 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751414574.024710   11546 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# ...
